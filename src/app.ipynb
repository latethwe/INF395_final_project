# %% [markdown]
# # API Notebook Stub
#
# Актуальная реализация API находится в `src/app.py`.
# Этот ноутбук оставлен как напоминание, чтобы не дублировать код и не расходиться со схемой данных.

# %%
from pathlib import Path
app_path = Path('/Users/zhasik/Desktop/krisha/src/app.py')
print('Use:', app_path)
print(app_path.read_text(encoding='utf-8')[:1200])
